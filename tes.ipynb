# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>PUNTO AMI PRIYONO</b></br>
# My current occupation is a financial and tax auditor

# %% [markdown]
# <i>I am interested in data science because my job is related to data analysis and data collection, which is auditing.</br>
# I belive if I learn about data science, it will help with my job and add a diversity of my skill besides accounting, tax regulation, and financial analysis.</i>

# %% [markdown]
# <h3>bellow this, an application of pyhton simple code which I currently start to learn, to print or show phyton version using print()</h3>

# %%
import sys
print("resulting in:")
print(sys.version)
# Out:
# resulting in:
# 3.10.6 (main, Oct 24 2022, 16:07:47) [GCC 11.2.0]

# %% [markdown]
# now this is some html code to show you some html tag and markdown code of: </br>
#  <ul>
#   <li>bulleted list</li>
#   <li>images</li>
#   <li>code syntax</li>
# </ul>
# above is example of bulleted list, now we will show images with img html tag
# <img src="https://nickelodeonuniverse.com/wp-content/uploads/Spongebob.png">
#
# third, this show you of markdown code syntax on json/JavaScript Object Notation, created by inserting code between '''json and ''' , which create result:</br>
# ```json
# {
#   "firstName": "punto",
#   "lastName": "priyono",
#   "age": 31
# }
# ```
